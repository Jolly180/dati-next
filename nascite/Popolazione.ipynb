# %%
import pandas as pd

# %%
df = pd.read_csv("DATI/nascite_morti_italia.csv",
                 sep=';',
                 index_col='Anno',
                 thousands='.'
                 )

df.sort_index(inplace=True)

# %%
df
# Out:
#       Popolazione     Nati   Morti
# Anno
# 1862     26328000   991000  815000
# 1863     26507000  1026000  824000
# 1864     26712000  1000000  802000
# 1865     26915000  1024000  812000
# 1866     27131000  1044000  798000
# ...           ...      ...     ...
# 2018     59937769   439747  633133
# 2019     59816673   420084  634417
# 2020     59641488   404892  740317
# 2021     59236213   400249  701346
# 2022     59030133   392598  713499
#
# [161 rows x 3 columns]

# %%
df['Saldo'] = df.Nati - df.Morti

# %%
df
# Out:
#       Popolazione     Nati   Morti   Saldo
# Anno
# 1862     26328000   991000  815000  176000
# 1863     26507000  1026000  824000  202000
# 1864     26712000  1000000  802000  198000
# 1865     26915000  1024000  812000  212000
# 1866     27131000  1044000  798000  246000
# ...           ...      ...     ...     ...
# 2018     59937769   439747  633133 -193386
# 2019     59816673   420084  634417 -214333
# 2020     59641488   404892  740317 -335425
# 2021     59236213   400249  701346 -301097
# 2022     59030133   392598  713499 -320901
#
# [161 rows x 4 columns]

# %%
df[['Nati', 'Morti', 'Saldo']].plot(figsize=(12, 4))
# Out:
# <Axes: xlabel='Anno'>

# %%
df.Popolazione.plot(figsize=(12, 4))
# Out:
# <Axes: xlabel='Anno'>
